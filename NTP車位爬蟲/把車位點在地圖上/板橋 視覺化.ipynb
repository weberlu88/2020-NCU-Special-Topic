# %% [markdown]
# 程式教學 (沒用到GeoPandas套件 但應該很好用)
# * [Easy Steps To Plot Geographic Data on a Map — Python](https://towardsdatascience.com/easy-steps-to-plot-geographic-data-on-a-map-python-11217859a2db) > 我是參考這篇
# * [GeoPandas 101: Plot any data with a latitude and longitude on a map](https://towardsdatascience.com/geopandas-101-plot-any-data-with-a-latitude-and-longitude-on-a-map-98e01944b972)
# * [Plot latitude longitude from CSV in Python 3.6](https://stackoverflow.com/questions/53233228/plot-latitude-longitude-from-csv-in-python-3-6) > 單純點散布圖看這個
#
# Map的取得方式: 先在Google map上手動找出板橋的邊界，再點到這個網站上，但是網站說範圍太大不給下載@@
# * https://www.openstreetmap.org/export#map=13/25.0061/121.4549

# %%
import pandas as pd

# %%
df = pd.read_csv('板橋區.csv', encoding='big5')
df
# Out:
#           id roadid        lat         lon     route district  \
# 0         20    K03  25.022574  121.479312     三民路一段      板橋區
# 1         21    K03  25.022503  121.479337     三民路一段      板橋區
# 2         22    K03  25.022169  121.479403     三民路一段      板橋區
# 3        682    K18  25.017591  121.482809       新北市       台灣
# 4        683    K18  25.017559  121.482767       新北市       台灣
# ...      ...    ...        ...         ...       ...      ...
# 2769  112032    KD6  25.008188  121.470035   民族路151巷      板橋區
# 2770  112033    KD6  25.008233  121.470058   民族路151巷      板橋區
# 2771  112034    KD6  25.008279  121.470080   民族路151巷      板橋區
# 2772  112163    K02  25.016735  121.472136     民生路二段      板橋區
# 2773  112164    K02  25.016693  121.472167  觀光街12巷1弄      板橋區
#
#                                      address
# 0                        220台灣新北市板橋區三民路一段48號
# 1                        220台灣新北市板橋區三民路一段52號
# 2                        220台灣新北市板橋區三民路一段72號
# 3     220台灣新北市板橋區Guang Fu Senior High School
# 4     220台灣新北市板橋區Guang Fu Senior High School
# ...                                      ...
# 2769                   220台灣新北市板橋區民族路151巷59號
# 2770                   220台灣新北市板橋區民族路151巷59號
# 2771                   220台灣新北市板橋區民族路151巷59號
# 2772         220台灣新北市板橋區民生路二段臨56之5號民生高架橋下迴轉道
# 2773                   220台灣新北市板橋區觀光街12巷1弄2號
#
# [2774 rows x 7 columns]

# %%
lon_min = df['lon'].min()
lon_max = df['lon'].max()
lat_min = df['lat'].min()
lat_max = df['lat'].max()

print('lon_min:', lon_min)
print('lon_max:', lon_max)
print('lat_min:', lat_min)
print('lat_max:', lat_max)
# Out:
# lon_min: 121.42595690000002
# lon_max: 121.48604950000001
# lat_min: 24.98705984
# lat_max: 25.03683063

# %%
import matplotlib.pyplot as plt

plt.scatter(x=df['lon'], y=df['lat'], s=1)
plt.show()

# %% [markdown]
# ### define the Bounding Box

# %%
# BBox = ((df.longitude.min(),   df.longitude.max(),      
#          df.latitude.min(), df.latitude.max())
BBox = ((121.4243, 121.4889,      
         24.9718, 25.0402))

ruh_m = plt.imread('板橋圖2.png')

# %% [markdown]
# ### Plotting

# %%
fig, ax = plt.subplots(figsize = (8,6)) # 4:3
ax.scatter(df['lon'], df['lat'], zorder=1, alpha= 0.2, c='b', s=2)
ax.set_title('Plotting Spatial Data on Riyadh Map')
ax.set_xlim(BBox[0],BBox[1])
ax.set_ylim(BBox[2],BBox[3])
ax.imshow(ruh_m, zorder=0, extent = BBox, aspect= 'equal')
